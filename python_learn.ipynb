# %% [markdown]
# <a href="https://colab.research.google.com/github/sudhanshubajaj30-stack/python/blob/main/python_learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assigning a value to variable can be done in '' or ""

# %%
import random

def get_choices():
  player_choice = input("Enter a choice (rock, paper, scissors): ")
  options = ["rock", "paper", "scissors"]
  computer_choice = random.choice(options)
  choices = {'player': player_choice, 'computer': computer_choice}
  return choices

  choices = get_choices()
  print(choices)

# %%
print(choices)
# Out:
# {'player': 'paper', 'computer': 'scissors'}
